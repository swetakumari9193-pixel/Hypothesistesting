# %%
1.What is a null hypothesis (H₀) and why is it important in hypothesis testing?
Ans- Null hypothesis is important in hypothesis a default statistical assumption that there is no significant effect, difference, or relationship between variables.It is baseline assumption that the researcher aims to disprove with data, allowing them to determine if any observed results are due to a real effect or simply random chance.

# %% [markdown]
# 2.What does the significance level (α) represent in hypothesis testing?
# Ans- It is Type 1 error,it is the probability of incorrectly rejecting a true null hypothesis.

# %% [markdown]
# 3. Differentiate between Type I and Type II errors.
# Ans- Type I errors rejecting a true null hypothesis also khown as false positive denoted by alpha.
#      Type II errors is false null hypothesis also known as false negative denoted by beta.

# %% [markdown]
# 4.Explain the difference between a one-tailed and two-tailed test. Give an example of each.
# Ans- One and Two-Tailed Tests are ways to identify the relationship between the statistical variables. For checking the relationship between variables in a single direction (Left or Right direction), we use a one-tailed test. A two-tailed test is used to check whether the relations between variables are in any direction or not.
# example of one tailed-Effect of participants of students in coding competition on their fear level.
# example of two tailed-Effect of new bill pass on the loan of farmers.

# %% [markdown]
# 5.A company claims that the average time to resolve a customer complaint is 10 minutes.
#
# A random sample of 9 complaints gives an average time of 12 minutes and a standard deviation of 3 minutes.
#
# At α = 0.05, test the claim.
# Ans-  Significance level alfa : 0.05
#      degree of freedom: n-1= 8
#      t=xbar-mu/s/underrootn
#      xbar=12     mu=10   s=3     n=9
#      t=12-10/(3/underroot9)=2/1=2
#      critical t-value= +-2.306
#      no enough evidance to improve average time to resolve a customer complaint.

# %% [markdown]
# 6.When should you use a Z-test instead of a t-test?
# Ans- we should use a Z-test when the population standard deviation is known and the sample size is large (n>=30).Assumption: Assumes a known population standard deviation and a normal distribution.Where as in case of t-testing it is for value less then 30.

# %% [markdown]
# 7.ans  before(Xi)                  after(Yi)                      difference(di)
#          50                           55                                5
#          60                           65                                5
#          58                           59                                1
#          55                           58                                3
#          62                           63                                1
#          56                           59                                3
#
#
#
#     SUM of difference= 18               no of samples= 6
#     d(bar)= sum of difference/n = 18/6= 3
#     standard deviation of difference(Sd) = 1.77 + 1.77 + 7.13 + 0.45 + 7.13 + 0.45 =18.7
#     varience is  18.7/6-1 = 3.75
#     standard deviation =under root(3.74)=1.934
#        calculate T- statistic
#        t = 3/(1.934/underroot6) = 3.802
#        alfa= 0.05
#        degree of freedom= n-1= 5
#        critical t-value =2.015
#        so we neglate the null hypothesis
#        hence significantly improved the employees productivity.

# %% [markdown]
# 8.
# ans- Chi-square test statistics is 16.667 thereis no significient evidence to conclude that product preference is not independent of gender.
